# %% [markdown]
# # GEO Prompt Audit Analysis
#
# Minimal notebook for analyzing prompt visibility results.

# %%
import pandas as pd

df = pd.read_csv('data/sample-results.csv')
df.head()

# %%
summary = df.groupby('engine', as_index=False)['total_score'].mean()
summary.sort_values('total_score', ascending=False)

# %% [markdown]
# Use the grouped scores to identify which engines understand and cite the brand best.
